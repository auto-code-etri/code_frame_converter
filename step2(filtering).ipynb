# %%
from json_tool import *
from filter_tool import *

# %% [markdown]
# ### 기존의 jsonl 형태로 저장된 코드들을 데이터 프레임 형태로 변환한다.

# %%
#jsonl_file = "code_source/Codes2_Codes3_base.jsonl"
jsonl_file = "code_source/Code_base_example.jsonl"
df = read_jsonl_file(jsonl_file)  # lines=True는 JSONL 파일용, False는 JSON 파일용
df
# Out:
#                            file_name  line_count  \
# 0         AboutDialog_function_1.cpp          27
# 1         AboutDialog_function_2.cpp           4
# 2        ActiveStatus_function_1.cpp           7
# 3      AdditionalFile_function_1.cpp           1
# 4          address_v4_function_1.cpp           4
# ...                              ...         ...
# 11602         x11grab_function_5.cpp          31
# 11603         x11grab_function_6.cpp          50
# 11604         x11grab_function_7.cpp          66
# 11605         x11grab_function_8.cpp           4
# 11606         x11grab_function_9.cpp          31
#
#                                                     code
# 0      CALLBACK DialogProc(HWND hWnd, UINT uMsg, WPAR...
# 1      void About()\n{\n\tDialogBox(g_hInstance, MAKE...
# 2      eActiveStatus GetStatusFromString(const std::s...
# 3      StringView externallyDefinedFunc() { return "Y...
# 4      address_v4 make_address_v4(const address_v4::b...
# ...                                                  ...
# 11602  int\n    init() {\n      static void *handle {...
# 11603  void\n  blend_cursor(Display *display, img_t &...
# 11604  int\n    init(const std::string &display_name,...
# 11605  void\n    refresh() {\n      x11::GetWindowAtt...
# 11606  capture_e\n    snapshot(const pull_free_image_...
#
# [11607 rows x 3 columns]

# %% [markdown]
# ### 500 라인 이상인 코드는 모두 제거한다.

# %%
lineno = 500
df2 = filter_by_numline_limit(df, lineno) # OO 라인 이상인 것은 전부 제거
df2
# Out:
#                            file_name  line_count  \
# 0         AboutDialog_function_1.cpp          27
# 1         AboutDialog_function_2.cpp           4
# 2        ActiveStatus_function_1.cpp           7
# 3      AdditionalFile_function_1.cpp           1
# 4          address_v4_function_1.cpp           4
# ...                              ...         ...
# 11593         x11grab_function_5.cpp          31
# 11594         x11grab_function_6.cpp          50
# 11595         x11grab_function_7.cpp          66
# 11596         x11grab_function_8.cpp           4
# 11597         x11grab_function_9.cpp          31
#
#                                                     code
# 0      CALLBACK DialogProc(HWND hWnd, UINT uMsg, WPAR...
# 1      void About()\n{\n\tDialogBox(g_hInstance, MAKE...
# 2      eActiveStatus GetStatusFromString(const std::s...
# 3      StringView externallyDefinedFunc() { return "Y...
# 4      address_v4 make_address_v4(const address_v4::b...
# ...                                                  ...
# 11593  int\n    init() {\n      static void *handle {...
# 11594  void\n  blend_cursor(Display *display, img_t &...
# 11595  int\n    init(const std::string &display_name,...
# 11596  void\n    refresh() {\n      x11::GetWindowAtt...
# 11597  capture_e\n    snapshot(const pull_free_image_...
#
# [11598 rows x 3 columns]

# %% [markdown]
# ### 코드 중에서 C/C++ 함수 형태가 아닌 코드들이 있다. 이러한 코드들은 제거한다

# %%
df3 = filter_by_non_cpp_functions(df2) # C/C++가 아닌 엔트리는 제거
df3
# Out:
# 100%|██████████| 11598/11598 [00:00<00:00, 214440.17it/s]
#                            file_name  line_count  \
# 0         AboutDialog_function_1.cpp          27
# 1         AboutDialog_function_2.cpp           4
# 2        ActiveStatus_function_1.cpp           7
# 3      AdditionalFile_function_1.cpp           1
# 4          address_v4_function_1.cpp           4
# ...                              ...         ...
# 10166         x11grab_function_5.cpp          31
# 10167         x11grab_function_6.cpp          50
# 10168         x11grab_function_7.cpp          66
# 10169         x11grab_function_8.cpp           4
# 10170         x11grab_function_9.cpp          31
#
#                                                     code
# 0      CALLBACK DialogProc(HWND hWnd, UINT uMsg, WPAR...
# 1      void About()\n{\n\tDialogBox(g_hInstance, MAKE...
# 2      eActiveStatus GetStatusFromString(const std::s...
# 3      StringView externallyDefinedFunc() { return "Y...
# 4      address_v4 make_address_v4(const address_v4::b...
# ...                                                  ...
# 10166  int\n    init() {\n      static void *handle {...
# 10167  void\n  blend_cursor(Display *display, img_t &...
# 10168  int\n    init(const std::string &display_name,...
# 10169  void\n    refresh() {\n      x11::GetWindowAtt...
# 10170  capture_e\n    snapshot(const pull_free_image_...
#
# [10171 rows x 3 columns]

# %% [markdown]
# ### 코드 중에서 파서의 오류로 함수가 1개 존재하는 것이 아니라 2개 이상 존재할 수 있다. 이러한 경우는 제거한다. (함수 1개만 허용)

# %%
df4 = filter_by_removing_multiple_functions(df3) # 코드에 함수가 여러개 있는 것은 제거
df4
# Out:
# 100%|██████████| 10171/10171 [00:00<00:00, 57426.44it/s]
#                           file_name  line_count  \
# 0        AboutDialog_function_1.cpp          27
# 1        AboutDialog_function_2.cpp           4
# 2       ActiveStatus_function_1.cpp           7
# 3     AdditionalFile_function_1.cpp           1
# 4         address_v4_function_1.cpp           4
# ...                             ...         ...
# 9752         x11grab_function_4.cpp          28
# 9753         x11grab_function_5.cpp          31
# 9754         x11grab_function_6.cpp          50
# 9755         x11grab_function_7.cpp          66
# 9756         x11grab_function_8.cpp           4
#
#                                                    code
# 0     CALLBACK DialogProc(HWND hWnd, UINT uMsg, WPAR...
# 1     void About()\n{\n\tDialogBox(g_hInstance, MAKE...
# 2     eActiveStatus GetStatusFromString(const std::s...
# 3     StringView externallyDefinedFunc() { return "Y...
# 4     address_v4 make_address_v4(const address_v4::b...
# ...                                                 ...
# 9752  int\n    init_shm() {\n      static void *hand...
# 9753  int\n    init() {\n      static void *handle {...
# 9754  void\n  blend_cursor(Display *display, img_t &...
# 9755  int\n    init(const std::string &display_name,...
# 9756  void\n    refresh() {\n      x11::GetWindowAtt...
#
# [9757 rows x 3 columns]

# %% [markdown]
# ### 코드의 라인 수 뿐만 아니라 토큰 수도 제한을 둔다. 5000개의 토근 이상인 경우, LLM이 처리하기에는 부담스러우므로 제거한다.

# %%
tokenno = 5000
df5 = filter_by_numtoken_limit(df4, tokenno)
df5
# Out:
# 100%|██████████| 9757/9757 [00:01<00:00, 5071.09it/s]
#                           file_name  line_count  \
# 0        AboutDialog_function_1.cpp          27
# 1        AboutDialog_function_2.cpp           4
# 2       ActiveStatus_function_1.cpp           7
# 3     AdditionalFile_function_1.cpp           1
# 4         address_v4_function_1.cpp           4
# ...                             ...         ...
# 9752         x11grab_function_4.cpp          28
# 9753         x11grab_function_5.cpp          31
# 9754         x11grab_function_6.cpp          50
# 9755         x11grab_function_7.cpp          66
# 9756         x11grab_function_8.cpp           4
#
#                                                    code
# 0     CALLBACK DialogProc(HWND hWnd, UINT uMsg, WPAR...
# 1     void About()\n{\n\tDialogBox(g_hInstance, MAKE...
# 2     eActiveStatus GetStatusFromString(const std::s...
# 3     StringView externallyDefinedFunc() { return "Y...
# 4     address_v4 make_address_v4(const address_v4::b...
# ...                                                 ...
# 9752  int\n    init_shm() {\n      static void *hand...
# 9753  int\n    init() {\n      static void *handle {...
# 9754  void\n  blend_cursor(Display *display, img_t &...
# 9755  int\n    init(const std::string &display_name,...
# 9756  void\n    refresh() {\n      x11::GetWindowAtt...
#
# [9757 rows x 3 columns]

# %% [markdown]
# ### 필터된 jsonl 파일을 저장한다.

# %%
output_jsonl_file = "code_filtered/Code_filtered_example.jsonl"
convert_df_to_jsonl(df5, output_jsonl_file)
# Out:
# JSONL 파일이 생성되었습니다!
